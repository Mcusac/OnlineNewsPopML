# %%
# Dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# store file path
file_path = '../Data/OnlineNewsPopularity.csv' # unclean
# file_path = '../Data/CleanDF.csv' # clean

# read in the csv file
df = pd.read_csv(file_path)

# view dataframe
df.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# ...

# %%
# summary of the variables 
print (df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19427 entries, 0 to 19426
# Data columns (total 31 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   19427 non-null  int64
#  1   parameterWaterBodyCategory                   19427 non-null  object
#  2   observedPropertyDeterminandCode              19427 non-null  object
#  3   procedureAnalysedFraction                    19427 non-null  object
#  4   procedureAnalysedMedia                       19427 non-null  object
#  5   resultUom                                    19427 non-null  object
#  6   phenomenonTimeReferenceYear                  19427 non-null  int64
#  7   parameterSamplingPeriod                      19427 non-null  object
#  8   resultMeanValue_x                            19427 non-null  float64
# ...

# %% [markdown]
# # Scatter Plots

# %% [markdown]
# # Correlation

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#                                              Unnamed: 0  \
# Unnamed: 0                                     1.000000
# phenomenonTimeReferenceYear                    0.156868
# resultMeanValue_x                             -0.005917
# PopulationDensity                              0.046393
# TerraMarineProtected_2016_2018                -0.072147
# TouristMean_1990_2020                         -0.113463
# VenueCount                                    -0.123819
# netMigration_2011_2018                         0.025062
# droughts_floods_temperature                    0.006944
# literacyRate_2010_2018                         0.010358
# combustibleRenewables_2009_2014                0.019285
# gdp                                           -0.080724
# composition_food_organic_waste_percent        -0.016273
# composition_glass_percent                     -0.087960
# composition_metal_percent                      0.035501
# composition_other_percent                     -0.019151
# ...

# %% [markdown]
# #### Using < (-0.8) or > (0.8) as requirement for being highly correlated
# PopulationDensity & netMigration_2011_2018: 0.822350
#
# PopulationDensity & composition_plastic_percent: 0.854375
#
# composition_wood_percent & composition_glass_percent: -0.858320
#
# composition_wood_percent & composition_plastic_percent: 0.826824
#
# #### There were some found to be even more highly correlated using a requirement of < (-0.9) or > (0.9)
# AVGresultMeanValue & resultMeanValue_x: 0.999880
#
# droughts_floods_temperature & : 0.991936

# %%
# Plot the correlation matrix as a heatmap
sns.heatmap(correlation_matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Cross-Tabulation

# %%
# Country
# waterBodyIdentifier
# parameterSamplingPeriod
# resultUom
# procedureAnalysedMedia
# procedureAnalysedFraction
# observedPropertyDeterminandCode
# parameterWaterBodyCategory


# Perform a cross tabulation
# Country
ct1 = pd.crosstab(df['Country'], df['waterBodyIdentifier'])
ct2 = pd.crosstab(df['Country'], df['parameterSamplingPeriod'])
ct3 = pd.crosstab(df['Country'], df['resultUom'])
ct4 = pd.crosstab(df['Country'], df['procedureAnalysedMedia'])
ct5 = pd.crosstab(df['Country'], df['procedureAnalysedFraction'])
ct6 = pd.crosstab(df['Country'], df['observedPropertyDeterminandCode'])
ct7 = pd.crosstab(df['Country'], df['parameterWaterBodyCategory'])

# waterBodyIdentifier
ct8 = pd.crosstab(df['waterBodyIdentifier'], df['parameterSamplingPeriod'])
ct9 = pd.crosstab(df['waterBodyIdentifier'], df['resultUom'])
ct10 = pd.crosstab(df['waterBodyIdentifier'], df['procedureAnalysedMedia'])
ct11 = pd.crosstab(df['waterBodyIdentifier'], df['procedureAnalysedFraction'])
ct12 = pd.crosstab(df['waterBodyIdentifier'], df['observedPropertyDeterminandCode'])
ct13 = pd.crosstab(df['waterBodyIdentifier'], df['parameterWaterBodyCategory'])

# parameterSamplingPeriod
ct14 = pd.crosstab(df['parameterSamplingPeriod'], df['resultUom'])
ct15 = pd.crosstab(df['parameterSamplingPeriod'], df['procedureAnalysedMedia'])
ct16 = pd.crosstab(df['parameterSamplingPeriod'], df['procedureAnalysedFraction'])
ct17 = pd.crosstab(df['parameterSamplingPeriod'], df['observedPropertyDeterminandCode'])
ct18 = pd.crosstab(df['parameterSamplingPeriod'], df['parameterWaterBodyCategory'])

# resultUom
ct19 = pd.crosstab(df['resultUom'], df['procedureAnalysedMedia'])
ct20 = pd.crosstab(df['resultUom'], df['procedureAnalysedFraction'])
ct21 = pd.crosstab(df['resultUom'], df['observedPropertyDeterminandCode'])
ct22 = pd.crosstab(df['resultUom'], df['parameterWaterBodyCategory'])

# procedureAnalysedMedia
ct23 = pd.crosstab(df['procedureAnalysedMedia'], df['procedureAnalysedFraction'])
ct24 = pd.crosstab(df['procedureAnalysedMedia'], df['observedPropertyDeterminandCode'])
ct25 = pd.crosstab(df['procedureAnalysedMedia'], df['parameterWaterBodyCategory'])

# procedureAnalysedFraction
ct26 = pd.crosstab(df['procedureAnalysedFraction'], df['observedPropertyDeterminandCode'])
ct27 = pd.crosstab(df['procedureAnalysedFraction'], df['parameterWaterBodyCategory'])

# observedPropertyDeterminandCode
ct28 = pd.crosstab(df['observedPropertyDeterminandCode'], df['parameterWaterBodyCategory'])

# %%
# Print the cross tabulation table
# print(ct1)
# print(ct2)
# print(ct3)
# print(ct4)
# print(ct5)
# print(ct6)
# print(ct7)
# print(ct8) # mostly 0's
# print(ct9) # some bodies of water seem to often be measured similarly
# print(ct10) # not much sediment at all
# print(ct11) # most all in 'total'
# print(ct12) # mostly 0's
# print(ct13) # mostly 'RW'
# print(ct14) # mostly 0's, some periods seemed to favor certain measurements
# print(ct15) # not much sediment at all
# print(ct16) # most all in 'total'
# print(ct17) # mostly 0's
# print(ct18) # mostly 'RW'
# print(ct19) # very little sediment
# print(ct20) # mostly 'total', some 'dissolved', less 'SPM'
# print(ct21) # some measurements are found more among cerrtain codes
# print(ct22) # mostly 'RW', some 'GW', less 'LW'
# print(ct23) # mostly 'total', some 'dissolved', less 'SPM'
# print(ct24) # not much sediment at all
# print(ct25) # mostly 'RW', some 'GW', less 'LW'
# print(ct26) # mostly 0's for dissolved and SPM. values mainly for 'total'
# print(ct27) # mostly 'RW', some 'GW', less 'LW'
# print(ct28) # mostly 'RW', some 'GW', less 'LW'
# Out:
# parameterWaterBodyCategory       GW  LW   RW
# observedPropertyDeterminandCode
# CAS_100-41-4                      8   0    3
# CAS_100-42-5                      0   0    1
# CAS_10061-02-6                    0   0    1
# CAS_1007-28-9                     1   0    0
# CAS_1024-57-3                     2   0    0
# ...                              ..  ..  ...
# EEA_3164-08-7                     0   1  843
# EEA_33-06-7                       5   0    0
# EEA_33-13-6                       0   1    0
# EEA_33-18-1                       2   0    0
# EEA_33-64-7                       5   0    0
#
# [182 rows x 3 columns]

# %% [markdown]
# # Group-Wise Averages

# %%
# Out:
# 34.438764797784664

# %% [markdown]
# # Other
