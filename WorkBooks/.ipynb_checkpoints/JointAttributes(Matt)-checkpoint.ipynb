# %%
# Dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# store file path
file_path = '../Data/ONPClean1.csv' # unclean
# file_path = '../Data/CleanDF.csv' # clean

# read in the csv file
df = pd.read_csv(file_path)

# view dataframe
df.head()
# Out:
#    Unnamed: 0                                                url  timedelta  \
# 0           1  http://mashable.com/2013/01/07/amazon-instant-...        731
# 1           2  http://mashable.com/2013/01/07/ap-samsung-spon...        731
# 2           3  http://mashable.com/2013/01/07/apple-40-billio...        731
# 3           4  http://mashable.com/2013/01/07/astronaut-notre...        731
# 4           5   http://mashable.com/2013/01/07/att-u-verse-apps/        731
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0              12               219         0.663594               1.0
# 1               9               255         0.604743               1.0
# 2               9               211         0.575130               1.0
# 3               9               531         0.503788               1.0
# 4              13              1072         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  ...  \
# 0                  0.815385          4               2  ...
# 1                  0.791946          3               1  ...
# 2                  0.663866          3               1  ...
# 3                  0.665635          9               0  ...
# 4                  0.540890         19              19  ...
#
#    avg_negative_polarity  min_negative_polarity  max_negative_polarity  \
# 0              -0.350000                 -0.600              -0.200000
# 1              -0.118750                 -0.125              -0.100000
# 2              -0.466667                 -0.800              -0.133333
# 3              -0.369697                 -0.600              -0.166667
# 4              -0.220192                 -0.500              -0.050000
#
#    title_subjectivity  title_sentiment_polarity  abs_title_subjectivity  \
# 0            0.500000                 -0.187500                0.000000
# 1            0.000000                  0.000000                0.500000
# 2            0.000000                  0.000000                0.500000
# 3            0.000000                  0.000000                0.500000
# 4            0.454545                  0.136364                0.045455
#
#    abs_title_sentiment_polarity  shares  day_of_week   data_channel
# 0                      0.187500     593          Mon  Entertainment
# 1                      0.000000     711          Mon            Bus
# 2                      0.000000    1500          Mon            Bus
# 3                      0.000000    1200          Mon  Entertainment
# 4                      0.136364     505          Mon           Tech
#
# [5 rows x 51 columns]

# %% [markdown]
# # Scatter Plots

# %%
# Create a scatter plot with x being 'shares' and y being 'price'
plt.scatter(df[''], df['shares'])

# Add labels and title
plt.xlabel('')
plt.ylabel('Shares')
plt.title('')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\ML1b\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.conda\envs\ML1b\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.conda\envs\ML1b\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19804\1333480278.py in <module>
#       1 # Create a scatter plot with x being 'shares' and y being 'price'
# ----> 2 plt.scatter(df['shares'], df['price'])
#       3
#       4 # Add labels and title
#       5 plt.xlabel('Shares')
#
# ~\.conda\envs\ML1b\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\.conda\envs\ML1b\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'price'

# %% [markdown]
# # Correlation

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#                               Unnamed: 0  timedelta  n_tokens_title  \
# Unnamed: 0                      1.000000  -0.998599        0.240772
# timedelta                      -0.998599   1.000000       -0.240320
# n_tokens_title                  0.240772  -0.240320        1.000000
# n_tokens_content                0.059771  -0.062867        0.018160
# n_unique_tokens                -0.003018   0.002866       -0.005318
# n_non_stop_words               -0.000328   0.000089       -0.004754
# n_non_stop_unique_tokens       -0.003979   0.003805       -0.005420
# num_hrefs                      -0.002307  -0.000832       -0.053496
# num_self_hrefs                 -0.067796   0.064530       -0.014856
# num_imgs                        0.021767  -0.027636       -0.008858
# num_videos                     -0.001400   0.000936        0.051460
# average_token_length           -0.136023   0.130465       -0.071403
# num_keywords                   -0.050293   0.046884       -0.006077
# kw_min_min                     -0.575715   0.591199       -0.110672
# kw_max_min                     -0.030011   0.029503       -0.005890
# kw_avg_min                     -0.132173   0.133225       -0.031400
# kw_min_max                      0.075857  -0.076590        0.012926
# kw_max_max                      0.622012  -0.637824        0.120841
# kw_avg_max                      0.485992  -0.493093        0.115746
# kw_min_avg                      0.155183  -0.157204       -0.002370
# kw_max_avg                      0.048571  -0.051820        0.006918
# kw_avg_avg                      0.157877  -0.163164        0.004296
# self_reference_min_shares       0.009567  -0.011438       -0.004563
# self_reference_max_shares       0.010991  -0.014501        0.000128
# self_reference_avg_sharess      0.012253  -0.015655        0.000661
# is_weekend                     -0.000560   0.000272       -0.005996
# LDA_00                         -0.082623   0.080894       -0.070038
# LDA_01                         -0.003656   0.004423        0.063568
# LDA_02                          0.141979  -0.141713        0.038365
# LDA_03                          0.031156  -0.030838        0.042208
# LDA_04                         -0.092500   0.092906       -0.065063
# global_subjectivity            -0.138151   0.133837       -0.056804
# global_sentiment_polarity      -0.159390   0.158646       -0.072226
# global_rate_positive_words     -0.209028   0.207604       -0.064951
# global_rate_negative_words     -0.012621   0.010266        0.015530
# rate_positive_words            -0.201196   0.198654       -0.066589
# rate_negative_words             0.069127  -0.071968        0.034186
# avg_positive_polarity          -0.130470   0.126344       -0.049619
# min_positive_polarity          -0.056269   0.054772       -0.025069
# max_positive_polarity          -0.102203   0.098288       -0.021662
# avg_negative_polarity           0.002766  -0.000507       -0.017096
# min_negative_polarity          -0.059687   0.062175       -0.029146
# max_negative_polarity           0.063780  -0.063239        0.011425
# title_subjectivity              0.015717  -0.015919        0.077245
# title_sentiment_polarity       -0.038318   0.038711        0.000240
# abs_title_subjectivity         -0.011032   0.011551       -0.146954
# abs_title_sentiment_polarity    0.002756  -0.002745        0.040550
# shares                         -0.009739   0.008662        0.008783
#
#                               n_tokens_content  n_unique_tokens  \
# Unnamed: 0                            0.059771        -0.003018
# timedelta                            -0.062867         0.002866
# n_tokens_title                        0.018160        -0.005318
# n_tokens_content                      1.000000        -0.004737
# n_unique_tokens                      -0.004737         1.000000
# n_non_stop_words                      0.017512         0.999572
# n_non_stop_unique_tokens              0.000373         0.999852
# num_hrefs                             0.423065        -0.004352
# num_self_hrefs                        0.304682         0.006620
# num_imgs                              0.342600         0.018802
# num_videos                            0.103699        -0.000597
# average_token_length                  0.167789         0.026407
# num_keywords                          0.072845        -0.003679
# kw_min_min                           -0.054345         0.001601
# kw_max_min                            0.000066        -0.000552
# kw_avg_min                           -0.003545        -0.000826
# kw_min_max                           -0.022786         0.000577
# kw_max_max                            0.058860        -0.001624
# kw_avg_max                           -0.096460         0.000805
# kw_min_avg                           -0.022286         0.004563
# kw_max_avg                           -0.030496        -0.002120
# kw_avg_avg                           -0.079624        -0.002083
# self_reference_min_shares            -0.030686         0.001036
# self_reference_max_shares             0.025657        -0.000222
# self_reference_avg_sharess           -0.013809         0.001992
# is_weekend                            0.052024        -0.003186
# LDA_00                                0.026218        -0.002213
# LDA_01                               -0.009724        -0.000827
# LDA_02                                0.087266        -0.006855
# LDA_03                               -0.140141        -0.003689
# LDA_04                                0.041265        -0.004260
# global_subjectivity                   0.127879        -0.000180
# global_sentiment_polarity             0.021937         0.000523
# global_rate_positive_words            0.133979         0.000014
# global_rate_negative_words            0.125013        -0.000877
# rate_positive_words                   0.098960        -0.000667
# rate_negative_words                   0.101053        -0.001657
# avg_positive_polarity                 0.135123        -0.000487
# min_positive_polarity                -0.261493         0.009193
# max_positive_polarity                 0.415706        -0.009054
# avg_negative_polarity                -0.130375         0.001453
# min_negative_polarity                -0.450603         0.009902
# max_negative_polarity                 0.225870        -0.007315
# title_subjectivity                    0.004484        -0.004678
# title_sentiment_polarity              0.023358        -0.002333
# abs_title_subjectivity                0.007136        -0.009242
# abs_title_sentiment_polarity          0.013439        -0.004217
# shares                                0.002459         0.000806
#
#                               n_non_stop_words  n_non_stop_unique_tokens  \
# Unnamed: 0                           -0.000328                 -0.003979
# timedelta                             0.000089                  0.003805
# n_tokens_title                       -0.004754                 -0.005420
# n_tokens_content                      0.017512                  0.000373
# n_unique_tokens                       0.999572                  0.999852
# n_non_stop_words                      1.000000                  0.999532
# n_non_stop_unique_tokens              0.999532                  1.000000
# num_hrefs                             0.005521                 -0.004983
# num_self_hrefs                        0.013598                  0.007584
# num_imgs                              0.028486                  0.014230
# num_videos                           -0.000899                 -0.000963
# average_token_length                  0.031554                  0.034185
# num_keywords                         -0.001439                 -0.004440
# kw_min_min                           -0.000352                  0.002001
# kw_max_min                           -0.000595                 -0.000615
# kw_avg_min                           -0.000892                 -0.000644
# kw_min_max                           -0.000553                 -0.000089
# kw_max_max                            0.000394                 -0.002032
# kw_avg_max                           -0.002939                 -0.002006
# kw_min_avg                            0.003284                  0.002510
# kw_max_avg                           -0.003408                 -0.003694
# kw_avg_avg                           -0.005415                 -0.005944
# self_reference_min_shares             0.000339                  0.000989
# self_reference_max_shares             0.000170                 -0.000077
# self_reference_avg_sharess            0.001614                  0.002009
# is_weekend                           -0.002082                 -0.003502
# LDA_00                               -0.001031                  0.000342
# LDA_01                               -0.002869                 -0.000965
# LDA_02                               -0.003286                 -0.004965
# LDA_03                               -0.009761                 -0.009781
# LDA_04                               -0.001072                 -0.002097
# global_subjectivity                   0.002565                  0.005498
# global_sentiment_polarity             0.000831                  0.002043
# global_rate_positive_words            0.001535                  0.005002
# global_rate_negative_words            0.001036                  0.002590
# rate_positive_words                   0.002421                  0.005258
# rate_negative_words                   0.001245                  0.001709
# avg_positive_polarity                 0.002285                  0.004671
# min_positive_polarity                 0.000904                  0.008380
# max_positive_polarity                 0.002062                 -0.002245
# avg_negative_polarity                -0.001372                 -0.001972
# min_negative_polarity                -0.001214                  0.004318
# max_negative_polarity                -0.000761                 -0.006708
# title_subjectivity                   -0.005389                 -0.005860
# title_sentiment_polarity             -0.001650                 -0.002910
# abs_title_subjectivity               -0.008511                 -0.008572
# abs_title_sentiment_polarity         -0.004391                 -0.005342
# shares                                0.000443                  0.000114
#
#                               num_hrefs  num_self_hrefs  num_imgs  ...  \
# Unnamed: 0                    -0.002307       -0.067796  0.021767  ...
# timedelta                     -0.000832        0.064530 -0.027636  ...
# n_tokens_title                -0.053496       -0.014856 -0.008858  ...
# n_tokens_content               0.423065        0.304682  0.342600  ...
# n_unique_tokens               -0.004352        0.006620  0.018802  ...
# n_non_stop_words               0.005521        0.013598  0.028486  ...
# n_non_stop_unique_tokens      -0.004983        0.007584  0.014230  ...
# num_hrefs                      1.000000        0.396452  0.342633  ...
# num_self_hrefs                 0.396452        1.000000  0.238586  ...
# num_imgs                       0.342633        0.238586  1.000000  ...
# num_videos                     0.114518        0.077458 -0.067336  ...
# average_token_length           0.222588        0.126879  0.033924  ...
# num_keywords                   0.125890        0.099578  0.088432  ...
# kw_min_min                    -0.043263       -0.012896 -0.043840  ...
# kw_max_min                     0.012844       -0.001233  0.001894  ...
# kw_avg_min                     0.008307       -0.001286 -0.005340  ...
# kw_min_max                    -0.020150       -0.025904 -0.000528  ...
# kw_max_max                     0.051265        0.002567  0.051337  ...
# kw_avg_max                    -0.019269       -0.064747  0.002217  ...
# kw_min_avg                     0.058920        0.039239  0.081029  ...
# kw_max_avg                     0.069692       -0.013629  0.064374  ...
# kw_avg_avg                     0.121419       -0.015615  0.145236  ...
# self_reference_min_shares     -0.004804       -0.031229  0.007142  ...
# self_reference_max_shares      0.080394        0.130187  0.035067  ...
# self_reference_avg_sharess     0.025239        0.022157  0.020898  ...
# is_weekend                     0.072279        0.047798  0.053242  ...
# LDA_00                        -0.020100       -0.021692 -0.150439  ...
# LDA_01                        -0.053803       -0.004631  0.050080  ...
# LDA_02                        -0.012531       -0.085045 -0.094515  ...
# LDA_03                         0.123786       -0.028775  0.208924  ...
# LDA_04                        -0.054977        0.135441 -0.022780  ...
# global_subjectivity            0.203464        0.115285  0.080468  ...
# global_sentiment_polarity      0.086859        0.090070  0.021082  ...
# global_rate_positive_words     0.056428        0.121140 -0.041582  ...
# global_rate_negative_words     0.032515        0.011433  0.024772  ...
# rate_positive_words            0.101663        0.142088 -0.021734  ...
# rate_negative_words            0.059817       -0.010187  0.040029  ...
# avg_positive_polarity          0.188236        0.098062  0.096446  ...
# min_positive_polarity         -0.082168       -0.072648 -0.024683  ...
# max_positive_polarity          0.286733        0.189922  0.155232  ...
# avg_negative_polarity         -0.152146       -0.058222 -0.072500  ...
# min_negative_polarity         -0.263576       -0.122071 -0.136522  ...
# max_negative_polarity          0.054948        0.039153  0.042644  ...
# title_subjectivity             0.043950       -0.011239  0.056815  ...
# title_sentiment_polarity       0.039041        0.026224  0.046310  ...
# abs_title_subjectivity         0.009443        0.008961 -0.013759  ...
# abs_title_sentiment_polarity   0.056525       -0.006709  0.063307  ...
# shares                         0.045404       -0.001900  0.039388  ...
#
#                               min_positive_polarity  max_positive_polarity  \
# Unnamed: 0                                -0.056269              -0.102203
# timedelta                                  0.054772               0.098288
# n_tokens_title                            -0.025069              -0.021662
# n_tokens_content                          -0.261493               0.415706
# n_unique_tokens                            0.009193              -0.009054
# n_non_stop_words                           0.000904               0.002062
# n_non_stop_unique_tokens                   0.008380              -0.002245
# num_hrefs                                 -0.082168               0.286733
# num_self_hrefs                            -0.072648               0.189922
# num_imgs                                  -0.024683               0.155232
# num_videos                                -0.010103               0.125659
# average_token_length                       0.222207               0.471383
# num_keywords                              -0.015890               0.062440
# kw_min_min                                 0.022866               0.018640
# kw_max_min                                 0.003920               0.010666
# kw_avg_min                                 0.004237               0.022614
# kw_min_max                                 0.001039              -0.021713
# kw_max_max                                -0.024163              -0.019990
# kw_avg_max                                 0.006972              -0.097967
# kw_min_avg                                 0.015884              -0.012181
# kw_max_avg                                 0.021071               0.008247
# kw_avg_avg                                 0.050004              -0.005528
# self_reference_min_shares                  0.029102               0.005626
# self_reference_max_shares                 -0.002418               0.039869
# self_reference_avg_sharess                 0.018423               0.022562
# is_weekend                                -0.009991               0.038172
# LDA_00                                    -0.104010               0.053271
# LDA_01                                     0.026534               0.040587
# LDA_02                                    -0.059227              -0.109331
# LDA_03                                     0.108755              -0.014059
# LDA_04                                     0.021312               0.042008
# global_subjectivity                        0.243984               0.518773
# global_sentiment_polarity                  0.086119               0.430893
# global_rate_positive_words                -0.107093               0.473331
# global_rate_negative_words                 0.060769               0.182928
# rate_positive_words                        0.050771               0.451048
# rate_negative_words                        0.194568               0.035689
# avg_positive_polarity                      0.456973               0.703558
# min_positive_polarity                      1.000000               0.009600
# max_positive_polarity                      0.009600               1.000000
# avg_negative_polarity                     -0.063571              -0.268784
# min_negative_polarity                      0.091270              -0.360871
# max_negative_polarity                     -0.183997              -0.005253
# title_subjectivity                         0.008327               0.052790
# title_sentiment_polarity                  -0.001301               0.076898
# abs_title_subjectivity                     0.016991              -0.017131
# abs_title_sentiment_polarity               0.011512               0.082966
# shares                                    -0.000040               0.010068
#
#                               avg_negative_polarity  min_negative_polarity  \
# Unnamed: 0                                 0.002766              -0.059687
# timedelta                                 -0.000507               0.062175
# n_tokens_title                            -0.017096              -0.029146
# n_tokens_content                          -0.130375              -0.450603
# n_unique_tokens                            0.001453               0.009902
# n_non_stop_words                          -0.001372              -0.001214
# n_non_stop_unique_tokens                  -0.001972               0.004318
# num_hrefs                                 -0.152146              -0.263576
# num_self_hrefs                            -0.058222              -0.122071
# num_imgs                                  -0.072500              -0.136522
# num_videos                                -0.115976              -0.138190
# average_token_length                      -0.324529              -0.278784
# num_keywords                               0.021114              -0.002656
# kw_min_min                                 0.017312               0.050316
# kw_max_min                                -0.005720              -0.003676
# kw_avg_min                                -0.003739               0.001290
# kw_min_max                                -0.004084               0.003446
# kw_max_max                                -0.018600              -0.054699
# kw_avg_max                                -0.021485               0.014258
# kw_min_avg                                -0.020031              -0.004458
# kw_max_avg                                -0.047610              -0.023987
# kw_avg_avg                                -0.072835              -0.020253
# self_reference_min_shares                 -0.040128              -0.011390
# self_reference_max_shares                 -0.053774              -0.047108
# self_reference_avg_sharess                -0.054093              -0.029052
# is_weekend                                -0.025661              -0.038512
# LDA_00                                     0.041026               0.039226
# LDA_01                                    -0.102900              -0.061209
# LDA_02                                     0.038317              -0.069130
# LDA_03                                    -0.114381              -0.025578
# LDA_04                                     0.120066               0.104233
# global_subjectivity                       -0.443187              -0.350070
# global_sentiment_polarity                  0.229764               0.285378
# global_rate_positive_words                -0.131794              -0.115422
# global_rate_negative_words                -0.352242              -0.478499
# rate_positive_words                       -0.034753               0.088708
# rate_negative_words                       -0.346947              -0.452522
# avg_positive_polarity                     -0.275705              -0.232209
# min_positive_polarity                     -0.063571               0.091270
# max_positive_polarity                     -0.268784              -0.360871
# avg_negative_polarity                      1.000000               0.748896
# min_negative_polarity                      0.748896               1.000000
# max_negative_polarity                      0.580108               0.080551
# title_subjectivity                        -0.075814              -0.057639
# title_sentiment_polarity                   0.085878               0.078795
# abs_title_subjectivity                    -0.006573              -0.010531
# abs_title_sentiment_polarity              -0.075594              -0.058398
# shares                                    -0.032029              -0.019297
#
#                               max_negative_polarity  title_subjectivity  \
# Unnamed: 0                                 0.063780            0.015717
# timedelta                                 -0.063239           -0.015919
# n_tokens_title                             0.011425            0.077245
# n_tokens_content                           0.225870            0.004484
# n_unique_tokens                           -0.007315           -0.004678
# n_non_stop_words                          -0.000761           -0.005389
# n_non_stop_unique_tokens                  -0.006708           -0.005860
# num_hrefs                                  0.054948            0.043950
# num_self_hrefs                             0.039153           -0.011239
# num_imgs                                   0.042644            0.056815
# num_videos                                 0.027251            0.061028
# average_token_length                      -0.194660           -0.040406
# num_keywords                               0.028036            0.016014
# kw_min_min                                -0.027172           -0.004379
# kw_max_min                                -0.000035            0.015680
# kw_avg_min                                -0.005206            0.011963
# kw_min_max                                -0.006318            0.022529
# kw_max_max                                 0.028523            0.005110
# kw_avg_max                                -0.022972            0.047235
# kw_min_avg                                -0.009388            0.045342
# kw_max_avg                                -0.024168            0.049935
# kw_avg_avg                                -0.046697            0.097761
# self_reference_min_shares                 -0.046718            0.005464
# self_reference_max_shares                 -0.022557            0.013754
# self_reference_avg_sharess                -0.043748            0.010175
# is_weekend                                 0.003032            0.023956
# LDA_00                                    -0.008738           -0.048812
# LDA_01                                    -0.039642            0.054447
# LDA_02                                     0.079632           -0.076511
# LDA_03                                    -0.074780            0.129062
# LDA_04                                     0.036605           -0.053996
# global_subjectivity                       -0.223191            0.114123
# global_sentiment_polarity                 -0.044238            0.023620
# global_rate_positive_words                -0.072669            0.109938
# global_rate_negative_words                 0.070557            0.090229
# rate_positive_words                       -0.199162           -0.024194
# rate_negative_words                        0.026644           -0.003934
# avg_positive_polarity                     -0.139768            0.052364
# min_positive_polarity                     -0.183997            0.008327
# max_positive_polarity                     -0.005253            0.052790
# avg_negative_polarity                      0.580108           -0.075814
# min_negative_polarity                      0.080551           -0.057639
# max_negative_polarity                      1.000000           -0.015788
# title_subjectivity                        -0.015788            1.000000
# title_sentiment_polarity                  -0.000470            0.232130
# abs_title_subjectivity                    -0.001877           -0.487172
# abs_title_sentiment_polarity              -0.017444            0.714528
# shares                                    -0.019300            0.021967
#
#                               title_sentiment_polarity  \
# Unnamed: 0                                   -0.038318
# timedelta                                     0.038711
# n_tokens_title                                0.000240
# n_tokens_content                              0.023358
# n_unique_tokens                              -0.002333
# n_non_stop_words                             -0.001650
# n_non_stop_unique_tokens                     -0.002910
# num_hrefs                                     0.039041
# num_self_hrefs                                0.026224
# num_imgs                                      0.046310
# num_videos                                    0.021980
# average_token_length                         -0.016718
# num_keywords                                  0.031705
# kw_min_min                                    0.032902
# kw_max_min                                    0.009511
# kw_avg_min                                    0.011894
# kw_min_max                                    0.007525
# kw_max_max                                   -0.029771
# kw_avg_max                                   -0.010713
# kw_min_avg                                    0.024973
# kw_max_avg                                    0.018949
# kw_avg_avg                                    0.035678
# self_reference_min_shares                     0.000570
# self_reference_max_shares                     0.004789
# self_reference_avg_sharess                    0.000930
# is_weekend                                    0.032343
# LDA_00                                        0.027982
# LDA_01                                       -0.006426
# LDA_02                                       -0.074275
# LDA_03                                        0.027687
# LDA_04                                        0.023665
# global_subjectivity                           0.034075
# global_sentiment_polarity                     0.238266
# global_rate_positive_words                    0.136469
# global_rate_negative_words                   -0.138152
# rate_positive_words                           0.144467
# rate_negative_words                          -0.185787
# avg_positive_polarity                         0.079529
# min_positive_polarity                        -0.001301
# max_positive_polarity                         0.076898
# avg_negative_polarity                         0.085878
# min_negative_polarity                         0.078795
# max_negative_polarity                        -0.000470
# title_subjectivity                            0.232130
# title_sentiment_polarity                      1.000000
# abs_title_subjectivity                       -0.240112
# abs_title_sentiment_polarity                  0.410205
# shares                                        0.012772
#
#                               abs_title_subjectivity  \
# Unnamed: 0                                 -0.011032
# timedelta                                   0.011551
# n_tokens_title                             -0.146954
# n_tokens_content                            0.007136
# n_unique_tokens                            -0.009242
# n_non_stop_words                           -0.008511
# n_non_stop_unique_tokens                   -0.008572
# num_hrefs                                   0.009443
# num_self_hrefs                              0.008961
# num_imgs                                   -0.013759
# num_videos                                 -0.021982
# average_token_length                        0.026586
# num_keywords                               -0.010992
# kw_min_min                                  0.008137
# kw_max_min                                  0.000671
# kw_avg_min                                  0.004847
# kw_min_max                                 -0.011066
# kw_max_max                                 -0.010491
# kw_avg_max                                 -0.015096
# kw_min_avg                                 -0.016834
# kw_max_avg                                 -0.012426
# kw_avg_avg                                 -0.023865
# self_reference_min_shares                   0.002361
# self_reference_max_shares                  -0.004935
# self_reference_avg_sharess                 -0.001442
# is_weekend                                 -0.035015
# LDA_00                                      0.001337
# LDA_01                                     -0.071821
# LDA_02                                      0.059309
# LDA_03                                     -0.013784
# LDA_04                                      0.009713
# global_subjectivity                        -0.003758
# global_sentiment_polarity                  -0.028717
# global_rate_positive_words                 -0.137288
# global_rate_negative_words                 -0.055071
# rate_positive_words                        -0.017876
# rate_negative_words                         0.040898
# avg_positive_polarity                       0.015141
# min_positive_polarity                       0.016991
# max_positive_polarity                      -0.017131
# avg_negative_polarity                      -0.006573
# min_negative_polarity                      -0.010531
# max_negative_polarity                      -0.001877
# title_subjectivity                         -0.487172
# title_sentiment_polarity                   -0.240112
# abs_title_subjectivity                      1.000000
# abs_title_sentiment_polarity               -0.400272
# shares                                      0.001481
#
#                               abs_title_sentiment_polarity    shares
# Unnamed: 0                                        0.002756 -0.009739
# timedelta                                        -0.002745  0.008662
# n_tokens_title                                    0.040550  0.008783
# n_tokens_content                                  0.013439  0.002459
# n_unique_tokens                                  -0.004217  0.000806
# n_non_stop_words                                 -0.004391  0.000443
# n_non_stop_unique_tokens                         -0.005342  0.000114
# num_hrefs                                         0.056525  0.045404
# num_self_hrefs                                   -0.006709 -0.001900
# num_imgs                                          0.063307  0.039388
# num_videos                                        0.055231  0.023936
# average_token_length                             -0.036953 -0.022007
# num_keywords                                      0.023533  0.021818
# kw_min_min                                        0.007645 -0.001051
# kw_max_min                                        0.016085  0.030114
# kw_avg_min                                        0.012165  0.030406
# kw_min_max                                        0.021184  0.003901
# kw_max_max                                       -0.006091  0.007863
# kw_avg_max                                        0.035188  0.044686
# kw_min_avg                                        0.054769  0.039551
# kw_max_avg                                        0.051628  0.064306
# kw_avg_avg                                        0.098671  0.110413
# self_reference_min_shares                         0.005261  0.055958
# self_reference_max_shares                         0.008720  0.047115
# self_reference_avg_sharess                        0.006897  0.057789
# is_weekend                                        0.036490  0.016958
# LDA_00                                           -0.028023 -0.003793
# LDA_01                                            0.034438 -0.010183
# LDA_02                                           -0.081729 -0.059163
# LDA_03                                            0.122120  0.083771
# LDA_04                                           -0.045538 -0.016622
# global_subjectivity                               0.091067  0.031604
# global_sentiment_polarity                         0.071898  0.004163
# global_rate_positive_words                        0.103391  0.000543
# global_rate_negative_words                        0.055872  0.006615
# rate_positive_words                              -0.003356 -0.013241
# rate_negative_words                              -0.026495 -0.005183
# avg_positive_polarity                             0.101191  0.012142
# min_positive_polarity                             0.011512 -0.000040
# max_positive_polarity                             0.082966  0.010068
# avg_negative_polarity                            -0.075594 -0.032029
# min_negative_polarity                            -0.058398 -0.019297
# max_negative_polarity                            -0.017444 -0.019300
# title_subjectivity                                0.714528  0.021967
# title_sentiment_polarity                          0.410205  0.012772
# abs_title_subjectivity                           -0.400272  0.001481
# abs_title_sentiment_polarity                      1.000000  0.027135
# shares                                            0.027135  1.000000
#
# [48 rows x 48 columns]

# %%
# Select the features with the highest correlation coefficients
important_features = correlation_matrix.index[correlation_matrix['shares'] > 0.3]

print(important_features)
# Out:
# Index(['shares'], dtype='object')

# %% [markdown]
# #### Nothing found to be correlated with shares variable
#
# #### Using < (-0.6) or > (0.6) as requirement for being highly correlated
#
# timedelta & kw_max_max: -0.637824
#
# #### Using < (-0.7) or > (0.7) as requirement for being highly correlated
#
# max_positive_polarity & avg_positive_polarity: 0.703558
#
# abs_title_subjectivity & title_subjectivity: 0.714528
#
# #### Using < (-0.9) or > (0.9) as requirement for being highly correlated
#
# n_non_stop_words & n_non_stop_unique_tokens: 0.999532
#
# n_unique_tokens & n_non_stop_words: 0.999572
#
# n_unique_tokens & n_non_stop_unique_tokens: 0.999852

# %%
# Plot the correlation matrix as a heatmap
sns.heatmap(correlation_matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Cross-Tabulation

# %%
# Perform a cross tabulation
ct = pd.crosstab(df['day_of_week'], df['data_channel'])

# Print the cross tabulation table
print(ct)
# Out:
# data_channel   Bus  Entertainment  Lifestyle  Socmed  Tech  World
# day_of_week
# Fri            832            972        305     332   989   2271
# Mon           1153           1358        322     337  1235   2256
# Sat            243            380        182     180   525    943
# Sun            343            536        210     137   396   1115
# Thu           1234           1231        358     463  1310   2671
# Tue           1182           1285        334     458  1474   2657
# Wed           1271           1295        388     416  1417   2648

# %% [markdown]
# Saturday and Sunday have evidence of being slow-news days relative to the rest of the week in each category.
#
# World news has the most instances with Lifestyle having the least.

# %% [markdown]
# # Group-Wise Averages

# %% [markdown]
# ### day_of_week

# %%
df.groupby('day_of_week')['shares'].mean()
# Out:
# day_of_week
# Fri    3285.181021
# Mon    3647.025822
# Sat    4078.185079
# Sun    3746.740592
# Thu    3178.599147
# Tue    3202.500677
# Wed    3303.405380
# Name: shares, dtype: float64

# %% [markdown]
# The weekend (Fri-Sun) seems to be the time when the most shares happen

# %%
df.groupby('day_of_week')['title_sentiment_polarity'].mean()
# Out:
# day_of_week
# Fri    0.067357
# Mon    0.065491
# Sat    0.097434
# Sun    0.090061
# Thu    0.070237
# Tue    0.073242
# Wed    0.063776
# Name: title_sentiment_polarity, dtype: float64

# %% [markdown]
# The polarity of the title appears to be higher on the weekends (Fri-Sun)

# %%
df.groupby('day_of_week')['rate_negative_words'].mean()
# Out:
# day_of_week
# Fri    0.295742
# Mon    0.290736
# Sat    0.284468
# Sun    0.289825
# Thu    0.287761
# Tue    0.283576
# Wed    0.284382
# Name: rate_negative_words, dtype: float64

# %% [markdown]
# Rate of negative words stats steady throughout the week.

# %% [markdown]
# ### data_channel

# %%
df.groupby('data_channel')['shares'].mean()
# Out:
# data_channel
# Bus              3063.018536
# Entertainment    2970.487034
# Lifestyle        3682.123392
# Socmed           3629.383125
# Tech             3072.283283
# World            3828.482110
# Name: shares, dtype: float64

# %% [markdown]
# World news has the most shares with Lifestyle and Socmed close behind.
#
# Entertainment jas the least amount of shares but not by a much larger margin then Bus or Tech.

# %%
df.groupby('data_channel')['title_sentiment_polarity'].mean()
# Out:
# data_channel
# Bus              0.080190
# Entertainment    0.064617
# Lifestyle        0.109075
# Socmed           0.097425
# Tech             0.086359
# World            0.053849
# Name: title_sentiment_polarity, dtype: float64

# %% [markdown]
# The polarity of the title is higher on Lifestyle and SocMed articles.
#
# World and Entertainment have the lowest average polarity score for their titles.

# %%
df.groupby('data_channel')['rate_negative_words'].mean()
# Out:
# data_channel
# Bus              0.258300
# Entertainment    0.305044
# Lifestyle        0.266885
# Socmed           0.250294
# Tech             0.250580
# World            0.320260
# Name: rate_negative_words, dtype: float64

# %% [markdown]
# Rate of negative words stats steady throug the categories other than World and Entertainment which are higher.

# %% [markdown]
# # Other
